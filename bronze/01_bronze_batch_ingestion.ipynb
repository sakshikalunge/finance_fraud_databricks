# %%
# CREATE RAW PATH
raw_path = "/Volumes/finance_fraudworkspace/bronze/raw_volume"

# %%
display(dbutils.fs.ls("/Volumes/finance_fraudworkspace/bronze/raw_volume"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Volumes/finance_fraudworkspace/bronze/raw_volume/accounts/</td><td>accounts/</td><td>0</td><td>1769273137000</td></tr><tr><td>dbfs:/Volumes/finance_fraudworkspace/bronze/raw_volume/customers/</td><td>customers/</td><td>0</td><td>1769273117000</td></tr><tr><td>dbfs:/Volumes/finance_fraudworkspace/bronze/raw_volume/merchants/</td><td>merchants/</td><td>0</td><td>1769273125000</td></tr><tr><td>dbfs:/Volumes/finance_fraudworkspace/bronze/raw_volume/raw_volume/</td><td>raw_volume/</td><td>0</td><td>1769602018000</td></tr><tr><td>dbfs:/Volumes/finance_fraudworkspace/bronze/raw_volume/transactions/</td><td>transactions/</td><td>0</td><td>1769273145000</td></tr></tbody></table></div>

# %%
# CREATE CUSTOMERS DATASET
customers_df = spark.read.format("csv") \
    .option("header", True) \
    .option("inferSchema", True) \
    .load(f"{raw_path}/customers")

customers_df.write.format("delta") \
    .mode("overwrite") \
    .saveAsTable("finance_fraudworkspace.bronze_managed.customers_bronze")

display(customers_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Customer_id</th><th>Full_name</th><th>DOB</th><th>Email</th><th>Risk_level</th><th>Created_timestamp</th></tr></thead><tbody><tr><td>C001</td><td>Alice Brown</td><td>1988-05-12</td><td>alice_brown@outlook.com</td><td>LOW</td><td>10-01-2023 09:15</td></tr><tr><td>C002</td><td>Bob Smith</td><td>1975-09-22</td><td>null</td><td>MEDIUM</td><td>14-02-2023 11:20</td></tr><tr><td>C003</td><td>Charlie Lee</td><td>null</td><td>charlielee@gmail.com</td><td>HIGH</td><td>01-03-2023 14:05</td></tr><tr><td>C004</td><td>David Wilson</td><td>1985-03-18</td><td>davidwilson1985@gmail.com</td><td>null</td><td>12-04-2023 16:45</td></tr><tr><td>C005</td><td>null</td><td>2000-07-25</td><td>evadunne@gmail.com</td><td>HIGH</td><td>20-05-2023 10:30</td></tr><tr><td>C006</td><td>Fatima Khan</td><td>1998-12-01</td><td>fatimakhxn@gmail.com</td><td>LOW</td><td>18-06-2023 08:10</td></tr><tr><td>C006</td><td>Fatima Khan</td><td>1998-12-01</td><td>fatimakhxn@gmail.com</td><td>LOW</td><td>18-06-2023 08:10</td></tr></tbody></table></div>

# %%
# CREATE ACCOUNTS DATASET
accounts_df = spark.read.format("csv") \
    .option("header", True) \
    .option("inferSchema", True) \
    .load(f"{raw_path}/accounts")

accounts_df.write.format("delta") \
    .mode("overwrite") \
    .saveAsTable("finance_fraudworkspace.bronze_managed.accounts_bronze")

display(accounts_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Account_id</th><th>Customer_id</th><th>Account_status</th><th>Credit_limit</th><th>Updated_ts</th></tr></thead><tbody><tr><td>A001</td><td>C001</td><td>ACTIVE</td><td>10000</td><td>2024-01-01</td></tr><tr><td>A002</td><td>C002</td><td>ACTIVE</td><td>5000</td><td>2024-01-01</td></tr><tr><td>A003</td><td>C003</td><td>BLOCKED</td><td>3000</td><td>2024-01-01</td></tr><tr><td>A004</td><td>C004</td><td>ACTIVE</td><td>null</td><td>2024-01-01</td></tr><tr><td>A005</td><td>C005</td><td>ACTIVE</td><td>7000</td><td>2024-01-01</td></tr><tr><td>A002</td><td>C002</td><td>BLOCKED</td><td>5000</td><td>2024-02-15</td></tr><tr><td>A006</td><td>C211</td><td>ACTIVE</td><td>4000</td><td>2024-01-01</td></tr></tbody></table></div>

# %%
# CREATE ACCOUNTS DATASET
merchants_df = spark.read.format("csv") \
    .option("header", True) \
    .option("inferSchema", True) \
    .load(f"{raw_path}/merchants")

merchants_df.write.format("delta") \
    .mode("overwrite") \
    .saveAsTable("finance_fraudworkspace.bronze_managed.merchants_bronze")

display(merchants_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Merchant_id</th><th>Merchant_name</th><th>Merchant_category</th><th>Merchant_country_code</th><th>Risk_level</th></tr></thead><tbody><tr><td>M001</td><td>Amazon</td><td>Retail</td><td>USA</td><td>LOW</td></tr><tr><td>M002</td><td>OnlineCasino</td><td>Gambling</td><td>MT</td><td>HIGH</td></tr><tr><td>M003</td><td>Airline</td><td>Travel</td><td>UK</td><td>MEDIUM</td></tr><tr><td>M004</td><td>ElectronicShop</td><td>Retail</td><td>DE</td><td>LOW</td></tr><tr><td>M005</td><td>CryptoExhange</td><td>Finance</td><td>null</td><td>HIGH</td></tr><tr><td>M006</td><td>UnknownStore</td><td>null</td><td>USA</td><td>null</td></tr></tbody></table></div>

# %%
# CREATE STREAMING TRANSACTIONS  

raw_path = "/Volumes/finance_fraudworkspace/bronze/raw_volume/transactions"
checkpoint_path = "/Volumes/finance_fraudworkspace/bronze/raw_volume/checkpoints/transactions_bronze"
schema_path = "/Volumes/finance_fraudworkspace/bronze/raw_volume/schemas/transactions_bronze"

transactions_stream = (
    spark.readStream
        .format("cloudFiles")  # Auto Loader
        .option("cloudFiles.format", "json")
        .option("cloudFiles.schemaLocation", schema_path)
        .load(raw_path)
)

query = (
    transactions_stream.writeStream
        .format("delta")
        .outputMode("append")
        .option("checkpointLocation", checkpoint_path)
        .trigger(availableNow=True)
        .toTable("finance_fraudworkspace.bronze_managed.transactions_bronze")
)

# %%
# DISPLAY STREAMING TRANSACTIONS
display(spark.table("finance_fraudworkspace.bronze_managed.transactions_bronze"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>account_id</th><th>amount</th><th>channel</th><th>country</th><th>currency</th><th>merchant_id</th><th>transaction_id</th><th>transaction_ts</th><th>_rescued_data</th></tr></thead><tbody><tr><td>A777</td><td>850</td><td>ONLINE</td><td>US</td><td>USD</td><td>M009</td><td>T9101</td><td>2026-01-27T18:00:00</td><td>null</td></tr><tr><td>A777</td><td>1250</td><td>ONLINE</td><td>US</td><td>USD</td><td>M009</td><td>T9102</td><td>2026-01-27T18:01:30</td><td>null</td></tr><tr><td>A888</td><td>95</td><td>POS</td><td>US</td><td>USD</td><td>M010</td><td>T9103</td><td>2026-01-27T18:02:10</td><td>null</td></tr><tr><td>A777</td><td>2100</td><td>ONLINE</td><td>US</td><td>USD</td><td>M011</td><td>T9104</td><td>2026-01-27T18:03:00</td><td>null</td></tr><tr><td>A999</td><td>20</td><td>POS</td><td>US</td><td>USD</td><td>M012</td><td>T9105</td><td>2026-01-27T18:04:20</td><td>null</td></tr><tr><td>A777</td><td>3300</td><td>ONLINE</td><td>US</td><td>USD</td><td>M009</td><td>T9106</td><td>2026-01-27T18:05:10</td><td>null</td></tr><tr><td>A888</td><td>4700</td><td>ONLINE</td><td>US</td><td>USD</td><td>M010</td><td>T9107</td><td>2026-01-27T18:06:40</td><td>null</td></tr><tr><td>A777</td><td>5200</td><td>ONLINE</td><td>US</td><td>USD</td><td>M009</td><td>T9108</td><td>2026-01-27T18:07:30</td><td>null</td></tr><tr><td>A999</td><td>45</td><td>POS</td><td>US</td><td>USD</td><td>M012</td><td>T9109</td><td>2026-01-27T18:08:15</td><td>null</td></tr><tr><td>A777</td><td>7600</td><td>ONLINE</td><td>US</td><td>USD</td><td>M011</td><td>T9110</td><td>2026-01-27T18:09:50</td><td>null</td></tr><tr><td>A777</td><td>1800</td><td>ONLINE</td><td>US</td><td>USD</td><td>M011</td><td>T9111</td><td>2026-01-27T18:10:30</td><td>null</td></tr><tr><td>A888</td><td>6200</td><td>ONLINE</td><td>US</td><td>USD</td><td>M010</td><td>T9112</td><td>2026-01-27T18:11:10</td><td>null</td></tr><tr><td>A999</td><td>60</td><td>POS</td><td>US</td><td>USD</td><td>M012</td><td>T9113</td><td>2026-01-27T18:12:45</td><td>null</td></tr><tr><td>A777</td><td>9100</td><td>ONLINE</td><td>US</td><td>USD</td><td>M009</td><td>T9114</td><td>2026-01-27T18:13:20</td><td>null</td></tr><tr><td>A888</td><td>130</td><td>POS</td><td>US</td><td>USD</td><td>M010</td><td>T9115</td><td>2026-01-27T18:14:05</td><td>null</td></tr><tr><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</ ...
